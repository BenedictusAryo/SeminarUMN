# %%
import pandas as pd

# %%
df = pd.read_csv("http://bit.ly/lamawaktubelajar")
df
# Out:
#    LamaWaktuBelajar  NilaiUlangan
# 0      TidakBelajar            65
# 1                 4            90
# 2                 4            96
# 3                 3            75
# 4      TidakBelajar            30
# 5                 2            60
# 6                 2            68
# 7                 3            85
# 8                 3            80
# 9                 1            62
# 10                4            92
# 11                4            98
# 12                3            88
# 13                2            65
# 14                3            70
# 15                1            40
# 16                4           100
# 17                2            70
# 18                3            80
# 19                2            60
